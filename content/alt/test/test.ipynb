# %%
raw_data = """
```json
[
  {
    "headline": "Aamir Khan's 'Sitaare Zameen Par' Sees Box Office Success After Initial Slow Start",
    "summary": "Aamir Khan's 'Sitaare Zameen Par' has emerged as a box office success, earning Rs 66.65 crore in its opening weekend. The film has surpassed the lifetime collections of earlier films. This marks a positive turn after the performance of 'Laal Singh Chaddha'.",
    "date": "2025-06-24",
    "location": "Mumbai, India",
    "tags": ["Aamir Khan", "Box Office", "Sitaare Zameen Par", "Bollywood"],
    "source": "Times of India",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHD3_mRyDnRlA47M313Emx150BnwskTIGhRro3mouID7los44k5P8w1K7xSHIZDjyaPzjCanxO0jq72UPn-pTaLfp6unmcB-F-Vpq3vrt2xcCGIQ3Mrdz05aSaEv1ujj7gecLu6SXtMKCOo858=",
    "type": "General Coverage"
  },
  {
    "headline": "FWICE Considers Ban on Diljit Dosanjh for Working with Pakistani Actress Hania Aamir in 'Sardaar Ji 3'",
    "summary": "The Federation of Western India Cine Employees (FWICE) is reportedly considering a ban on Diljit Dosanjh for including Pakistani actress Hania Aamir in his upcoming film 'Sardaar Ji 3', sparking controversy and debate within the industry.",
    "date": "2025-06-23",
    "location": "Mumbai, India",
    "tags": ["Diljit Dosanjh", "Hania Aamir", "FWICE", "Sardaar Ji 3", "Bollywood", "Controversy"],
    "source": "Bollywood Hungama",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHIBlkL8jRwzQ2isKXNoLdNGqyesVZDZ8yJ1fEtQlj8Llw8mFKqW49QrHFrdcAV0pD0iNsNqiQ4zL21f6aO-Lja_EkYpVVzrS2oWBiUilTcgLhfcr0sqiYHL2uT_A==",
    "type": "General Coverage"
  },
  {
    "headline": "Fire Destroys Anupamaa Set in Film City; AICWA Demands Judicial Probe",
    "summary": "A fire broke out and destroyed the set of the popular TV show 'Anupamaa' in Film City, Mumbai. The All Indian Cine Workers Association (AICWA) is calling for a judicial probe and FIR to investigate the cause of the fire.",
    "date": "2025-06-23",
    "location": "Mumbai, India",
    "tags": ["Fire", "Anupamaa", "Film City", "AICWA", "Investigation", "TV Show"],
    "source": "Bollywood Hungama",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHIBlkL8jRwzQ2isKXNoLdNGqyesVZDZ8yJ1fEtQlj8Llw8mFKqW49QrHFrdcAV0pD0iNsNqiQ4zL21f6aO-Lja_EkYpVVzrS2oWBiUilTcgLhfcr0sqiYHL2uT_A==",
    "type": "General Coverage"
  },
  {
    "headline": "Salman Khan Reveals Health Struggles with Brain Aneurysm and Trigeminal Neuralgia",
    "summary": "Bollywood actor Salman Khan disclosed that he has been battling a brain aneurysm and trigeminal neuralgia. He shared details about his health conditions. This announcement has prompted discussions about these medical issues.",
    "date": "2025-06-23",
    "location": "Mumbai, India",
    "tags": ["Salman Khan", "Health", "Brain Aneurysm", "Trigeminal Neuralgia", "Bollywood"],
    "source": "Hindustan Times",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHd97W5dGzK2vD8F7wHk0mJ5o0R8G_8_FzK-uXF8-5Q_t_t_4u-C9fI9l9X7l-14d8uK-t_14d8uK-t_14d8uK-t_14d8uK-t_14d8uK-t_14d8uK-t_",
    "type": "General Coverage"
  },
  {
    "headline": "Vineet Kumar Singh Recounts Being Stranded Due to Airspace Closure",
    "summary": "Actor Vineet Kumar Singh recently shared his experience of being stranded in the Middle East due to an unexpected airspace closure. He was traveling back to Mumbai from Dubai. He detailed the challenges he faced during the unexpected delay.",
    "date": "2025-06-24",
    "location": "Mumbai, India",
    "tags": ["Vineet Kumar Singh", "Airspace Closure", "Travel", "Bollywood"],
    "source": "Hindustan Times",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGpK8UocTRMeTJIeQLzt5lSvasC-yBiZheZ5woCQdgdoQ9VsHoC6NKSC_v77_7EKZlC92qh3qcfQ8zztIh27B9PEFpQDwJBf0kYiN7N09so69gXO24IBgv3Yzp1aSYGYDjMXKe8N2IJM_2dEuxEHpgwAQ==",
    "type": "General Coverage"
  },
  {
    "headline": "Sunny Deol Reflects on 35 Years of 'Ghayal'",
    "summary": "Sunny Deol commemorated the 35th anniversary of his iconic film 'Ghayal', remembering his role as Ajay Mehra. He acknowledged it as his first blockbuster and a significant milestone in his career. The film's anniversary brought a wave of nostalgia.",
    "date": "2025-06-24",
    "location": "Mumbai, India",
    "tags": ["Sunny Deol", "Ghayal", "Anniversary", "Bollywood", "Ajay Mehra"],
    "source": "Mid-day",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHY6bYB7jT87lJNn-WAAT0gJ9RyjH_HG82gkCDl3gml4RM9o-USMtgD93amv6Ri1Ph5CTIWlBQEQZy7pwOJeA8eZLhqTwcCQhYTVhKEwulogWkBWhX_8CURHZdgeLfHEnPDSh74HANFF7AF86CiucEA",
    "type": "Personalized Coverage"
  },
  {
    "headline": "Kiara Advani Approached for Meena Kumari Biopic",
    "summary": "Kiara Advani has reportedly been approached to play the lead role in a biopic about the legendary actress Meena Kumari. The film has also received the approval of the Amrohi family. Discussions are underway regarding the project.",
    "date": "2025-06-24",
    "location": "Mumbai, India",
    "tags": ["Kiara Advani", "Meena Kumari", "Biopic", "Bollywood", "Amrohi family"],
    "source": "Hindustan Times",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGpK8UocTRMeTJIeQLzt5lSvasC-yBiZheZ5woCQdgdoQ9VsHoC6NKSC_v77_7EKZlC92qh3qcfQ8zztIh27B9PEFpQDwJBf0kYiN7N09so69gXO24IBgv3Yzp1aSYGYDjMXKe8N2IJM_2dEuxEHpgwAQ==",
    "type": "Personalized Coverage"
  },
  {
    "headline": "Vikram Bhatt on 23 years of Awara Paagal Deewana, Sequel in the Works",
    "summary": "Vikram Bhatt reflected on the 23rd anniversary of his film 'Awara Paagal Deewana'. He confirmed that a sequel is very much in development. The original film was a comedy thriller, and fans are anticipating the new installment.",
    "date": "2025-06-23",
    "location": "Mumbai, India",
    "tags": ["Vikram Bhatt", "Awara Paagal Deewana", "Sequel", "Bollywood"],
    "source": "Bollywood Hungama",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHIBlkL8jRwzQ2isKXNoLdNGqyesVZDZ8yJ1fEtQlj8Llw8mFKqW49QrHFrdcAV0pD0iNsNqiQ4zL21f6aO-Lja_EkYpVVzrS2oWBiUilTcgLhfcr0sqiYHL2uT_A==",
    "type": "Personalized Coverage"
  },
  {
    "headline": "Air India Staff Dances In Office, Days After Ahmedabad Plane Crash, Sparks Controversy",
    "summary": "A video of Air India staff dancing in the office, shortly after the Ahmedabad plane crash, has gone viral and triggered criticism online. Netizens are calling the behavior insensitive given the recent tragedy.",
    "date": "2025-06-24",
    "location": "Ahmedabad, India",
    "tags": ["Air India", "Plane Crash", "Controversy", "Viral Video", "Social Media"],
    "source": "BollywoodShaadis",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGaT09xVu1rWaksSL6-S76-TNgp5FwlZcqCdYP7Vo83pqgvwF-uDzprOSOZx375F5hr7uvB4i7Q-dUDsMA8ho_Wvaxi_ncH71mX-n7aKZXF0TlPzN-ex5nlSTOFZg==",
    "type": "Trending & Viral"
  },
  {
    "headline": "Randeep Hooda Says He Was Given a 'Bowl to Pee' During Wedding with Lin Laishram",
    "summary": "Randeep Hooda made a surprising revelation, stating that he was provided with a bowl to relieve himself during his wedding ceremonies with Lin Laishram, citing the length and traditional requirements of the rituals.",
    "date": "2025-06-24",
    "location": "Mumbai, India",
    "tags": ["Randeep Hooda", "Lin Laishram", "Wedding", "Bollywood", "Viral"],
    "source": "Hindustan Times",
    "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFRIkKpC-hNDQ1yzqBJcnCbhIhRi0rPCensOUVLcLeAfiNR4-QraCvVCxCIObstht0kM-ZLT-vgoftv_2L4CHwzKHjjAtwlSMLucgVTe3BYFA2L4Tzwz67UTgwnsDzZqEW-y--sb7l4ZYKHOi7Mm8aW55vTeyo71a4=",
    "type": "Trending & Viral"
  }
]
```
"""

# %%
start_index = raw_data.find('json')
if start_index != -1:
    # Start extracting 4 chars after 'json'
    extracted = raw_data[start_index + 5 : -4]
    print(extracted)
else:
    print("No 'json' found.")
# Out:
# [
#   {
#     "headline": "Aamir Khan's 'Sitaare Zameen Par' Sees Box Office Success After Initial Slow Start",
#     "summary": "Aamir Khan's 'Sitaare Zameen Par' has emerged as a box office success, earning Rs 66.65 crore in its opening weekend. The film has surpassed the lifetime collections of earlier films. This marks a positive turn after the performance of 'Laal Singh Chaddha'.",
#     "date": "2025-06-24",
#     "location": "Mumbai, India",
#     "tags": ["Aamir Khan", "Box Office", "Sitaare Zameen Par", "Bollywood"],
#     "source": "Times of India",
#     "link": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHD3_mRyDnRlA47M313Emx150BnwskTIGhRro3mouID7los44k5P8w1K7xSHIZDjyaPzjCanxO0jq72UPn-pTaLfp6unmcB-F-Vpq3vrt2xcCGIQ3Mrdz05aSaEv1ujj7gecLu6SXtMKCOo858=",
#     "type": "General Coverage"
#   },
#   {
#     "headline": "FWICE Considers Ban on Diljit Dosanjh for Working with Pakistani Actress Hania Aamir in 'Sardaar Ji 3'",
# ...

# %%
import json
objects = json.loads(extracted)

# %%
for object in objects:
    for key, value in object.items():
        print(f"{key}: {value}")
    print("\n")
# Out:
# headline: Aamir Khan's 'Sitaare Zameen Par' Sees Box Office Success After Initial Slow Start
# summary: Aamir Khan's 'Sitaare Zameen Par' has emerged as a box office success, earning Rs 66.65 crore in its opening weekend. The film has surpassed the lifetime collections of earlier films. This marks a positive turn after the performance of 'Laal Singh Chaddha'.
# date: 2025-06-24
# location: Mumbai, India
# tags: ['Aamir Khan', 'Box Office', 'Sitaare Zameen Par', 'Bollywood']
# source: Times of India
# link: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHD3_mRyDnRlA47M313Emx150BnwskTIGhRro3mouID7los44k5P8w1K7xSHIZDjyaPzjCanxO0jq72UPn-pTaLfp6unmcB-F-Vpq3vrt2xcCGIQ3Mrdz05aSaEv1ujj7gecLu6SXtMKCOo858=
# type: General Coverage
#
#
# headline: FWICE Considers Ban on Diljit Dosanjh for Working with Pakistani Actress Hania Aamir in 'Sardaar Ji 3'
# ...

# %%
import requests

url = "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFRIkKpC-hNDQ1yzqBJcnCbhIhRi0rPCensOUVLcLeAfiNR4-QraCvVCxCIObstht0kM-ZLT-vgoftv_2L4CHwzKHjjAtwlSMLucgVTe3BYFA2L4Tzwz67UTgwnsDzZqEW-y--sb7l4ZYKHOi7Mm8aW55vTeyo71a4="
response = requests.get(url, allow_redirects=True)
print(response.url)  # This will show the actual destination if allowed
# Out:
# https://www.hindustantimes.com/entertainment/bollywood/page-3

# %%
import requests
from bs4 import BeautifulSoup
import urllib.parse


def fetch_actual_news_link(headline, source_name, user_agent=None):
    """
    Given a headline and a source name, fetch the actual news article link
    by searching it on Google.

    Args:
        headline (str): The headline of the article.
        source_name (str): The source publication (e.g., "Hindustan Times").
        user_agent (str): Optional user-agent string for the request.

    Returns:
        str | None: The actual article link if found, otherwise None.
    """
    query = f"{headline} site:{source_name.replace(' ', '')}.com"
    url = "https://www.google.com/search?q=" + urllib.parse.quote(query)

    headers = {
        "User-Agent": user_agent
        or "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
           "AppleWebKit/537.36 (KHTML, like Gecko) "
           "Chrome/114.0.0.0 Safari/537.36"
    }

    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"Error: Got status code {response.status_code}")
        return None

    soup = BeautifulSoup(response.content, "html.parser")

    # Try extracting links from the search results
    for a_tag in soup.find_all("a"):
        href = a_tag.get("href", "")
        if href.startswith("/url?q=") and source_name.replace(' ', '').lower() in href.lower():
            actual_link = href.split("&")[0].replace("/url?q=", "")
            return actual_link

    return None


# Example usage
headline = "Randeep Hooda Says He Was Given a 'Bowl to Pee' During Wedding with Lin Laishram"
source_name = "Hindustan Times"

url = fetch_actual_news_link(headline, source_name)
if url:
    print(f"Actual news link: {url}")
else:
    print("Could not find the actual link.")
# Out:
# Could not find the actual link.

# %%
import requests

x = "AIzaSyDHWdkuC6RUMbG3ZAQuHRaY_g9CfmdRZL8"
y = "03239f51a25ce431c"

def search_google_api(query):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {"key": x, "cx": y, "q": query}
    resp = requests.get(url, params=params).json()
    links = [item["link"] for item in resp.get("items", [])]
    return links

# Usage
results = search_google_api(f"{headline} {source_name}")
if results:
    print("Top link:", results[0])
# Out:
# Top link: https://www.hindustantimes.com/entertainment/bollywood/randeep-hooda-says-he-was-given-a-bowl-to-pee-lin-laishram-was-not-allowed-to-smile-during-their-wedding-in-manipur-101750492988874.html
